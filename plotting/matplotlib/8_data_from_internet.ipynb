# %%
# %matplotlib inline
from pylab import *

# %%
def graph_data(stock):
    stock_price_url = 'http://chartapi.finance.yahoo.com/instrument/1.0/' + stock + '/'


x = [1, 2, 3, 4, 5]
y = [22, 45, 33, 11, 94]

x2 = [1, 3, 5, 7, 9]
y2 = [43, 67, 23, 17, 73]


xlabel('x')
ylabel('y')
title('Interesting Graph\nCheck it out')

# line
plot(x, y, label='First line')
plot(x2, y2, label='Second line')


legend()
show()
